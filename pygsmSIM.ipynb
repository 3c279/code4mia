# %%
# --------------------------------------------  Simulciones PyGSM  -----------------------------------------

# distintas simulciones utilizando pygsm, 
#  Variando la freuencia en MHz correspondientes a distintos redshift 
#            z = {13,14,15,16,17,18,19,20,21}

# correspondiente a la absorcion medida por EDGES
# las figuras parecen similares, pero los valores de escala van variando

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pygsm import GlobalSkyModel2016
from pygsm import GlobalSkyModel

# %%
from pygsm import GlobalSkyModel

# %%
#  Z = 13   redshift
#  longitud de onda = 2.94 m
#  frecuencia v = 100 MHz 

gsm = GlobalSkyModel()
gsm.generate(100)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [7], line 3
#       1 gsm = GlobalSkyModel()
#       2 gsm.generate(100)
# ----> 3 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 14   redshift
#  longitud de onda = 3,15 m
#  frecuencia v = 94,6 MHz 

gsm = GlobalSkyModel()
gsm.generate(194)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [8], line 3
#       1 gsm = GlobalSkyModel()
#       2 gsm.generate(194)
# ----> 3 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 15   redshift
#  longitud de onda = 3,36 m
#  frecuencia v = 88,75 MHz 

gsm = GlobalSkyModel()
gsm.generate(88.75)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [10], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(88.75)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 16  redshift
#  longitud de onda = 3,57 m
#  frecuencia v = 83.52 MHz 

gsm = GlobalSkyModel()
gsm.generate(83.52)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [11], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(83.52)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 17   redshift
#  longitud de onda = 3,78 m
#  frecuencia v = 78,88 MHz 

gsm = GlobalSkyModel()
gsm.generate(78.88)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [12], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(78.88)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 18   redshift
#  longitud de onda = 3,98 m
#  frecuencia v = 74,73 MHz 

gsm = GlobalSkyModel()
gsm.generate(74.73)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [13], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(74.73)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 19   redshift
#  longitud de onda = 4,2 m
#  frecuencia v = 71 MHz 

gsm = GlobalSkyModel()
gsm.generate(71)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [14], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(71)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 20   redshift
#  longitud de onda = 4,41 m
#  frecuencia v = 67,62 MHz 

gsm = GlobalSkyModel()
gsm.generate(67.62)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [15], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(67.62)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 21  redshift
#  longitud de onda = 4,62 m
#  frecuencia v = 64,54 MHz 

gsm = GlobalSkyModel()
gsm.generate(64.54)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [16], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(64.54)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 22   redshift
#  longitud de onda = 4,83 m
#  frecuencia v = 61,74 MHz 

gsm = GlobalSkyModel()
gsm.generate(61.74)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [18], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(61.74)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
#  Z = 45   redshift
#  longitud de onda = m
#  frecuencia v = 30 MHz 

gsm = GlobalSkyModel()
gsm.generate(30)
gsm.view(logged=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [22], line 7
#       5 gsm = GlobalSkyModel()
#       6 gsm.generate(30)
# ----> 7 gsm.view(logged=True)
#
# File ~/PyGSM/pygsm/pygsm.py:194, in GlobalSkyModel.view(self, idx, logged)
#     191     gmap = np.log2(gmap)
#     193 hp.mollview(gmap, coord='G', title='Global Sky Model %s, %s' % (str(freq), self.basemap))
# --> 194 if not plt:
#     195     import pylab as plt
#     196 plt.show()
#
# UnboundLocalError: local variable 'plt' referenced before assignment

# %%
# como ejemplo si estubiera ubicado en Auger.

from pygsm import GSMObserver
from datetime import datetime

# Setup observatory location - in this case, Auger, Argentina
(latitude, longitude, elevation) = ('-35.4667', '-69.3068', 1400)
ov = GSMObserver()
ov.lon = longitude
ov.lat = latitude
ov.elev = elevation
ov.date = datetime(2000, 8, 10, 23, 0)

# %%
ov.generate(1400)
d = ov.view(logged=True)

# %%
d = ov.view_observed_gsm(logged=True)
